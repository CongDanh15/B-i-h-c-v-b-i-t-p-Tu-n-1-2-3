# %% [markdown]
# <a href="https://colab.research.google.com/github/CongDanh15/BT-AI/blob/main/Tuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ('text.txt',mode='w') as accounts :
  accounts.write('1 Nguyen Thanh Cong Danh 8.0\n') # \n co nghia la xuong dong
  accounts.write('2 Nguyen Dinh Khoi 9.0\n')

# %%
with open ('text1.txt',mode='w') as accounts :
  print('7:00,Nguyen Thanh Cong Danh dung gio',file=accounts)
  print('7:30,Nguyen Dinh Khoi di tre',file=accounts)

# %%
with open ('text.txt',mode='r') as accounts :
  print(f'{'name':<20}{'score':>20}')
  for record in accounts:
    name,score =record.split()
    print(f'{name:<20}{score:>20}')
# Out:
#   File "<ipython-input-14-884b218d9209>", line 2
#     print(f'{'name':<20}{'score':>20}')
#                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd 
url = 'Book1.csv'
dataframe = pd.read_csv(url) 
dataframe.head(10)
dataframe['Name']
# Out:
#    stt      mssv   ho va ten  diem
# 0    1  20104054  Tran Van A  10.0
# 1    2  20104055  Tran Van B   9.9
# 2    3  20104056  Tran Van C   9.8
# 3    4  20104057  Tran Van D   9.7
# 4    5  20104058  Tran Van E   9.6

# %%
import pandas as pd 
#Create dataframe 
dataframe=pd.DataFrame()
#Add colums
dataframe['Name']=['Nguyen Van A','Le Thi B']
dataframe['student ID']=[20104019,20104033]
dataframe['score']=[8.5,9.5]
dataframe
# Out:
#            Name  student ID  score
# 0  Nguyen Van A    20104019    8.5
# 1      Le Thi B    20104033    9.5

# %%
import pandas as pd
url='pybook2.csv'
df = pd.read_csv(url)
df[(df['Faculty']=='CKM') & (df['DIEM']>=7) & (df['Year']>20)]
# Out:
#    STT      MSSV              HO TEN  DIEM  Year Faculty
# 3    4  20104013        Le Thanh Hon     8    22     CKM
# 9   10  20104019  Do Hoang Dieu Linh    10    23     CKM

# %%
import pandas as pd
url='pybook2.csv'
df = pd.read_csv(url)
# Select unique values 
dataframe ['Faculty'].unique()
array (['CKM','CNM'],dtype=object)

# %%
import pandas as pd
url='pybook2.csv'
df = pd.read_csv(url)
df.drop('MSSV', axis= 1).head(7)
# Out:
#    STT            HO TEN  DIEM  Year Faculty
# 0    1  Nguyen Minh Sang    10    20     CKM
# 1    2  Nguyen Cong Danh    10    19     CKD
# 2    3      Le Quang Duc     9    18     DDT
# 3    4      Le Thanh Hon     8    22     CKM
# 4    5    Tran Minh Khoa     5    20     CLC
# 5    6      Le Hoang Kha     7    19     CKM
# 6    7   Nguyen Thi Dung     6    24     DDT

# %%
import pandas as pd
url='pybook2.csv'
df = pd.read_csv(url)
df.groupby('Year').mean()
df.groupby('Year').count()
# Out:
#       STT  MSSV  HO TEN  DIEM  Faculty
# Year
# 18      1     1       1     1        1
# 19      3     3       3     3        3
# 20      3     3       3     3        3
# 22      1     1       1     1        1
# 23      1     1       1     1        1
# 24      1     1       1     1        1

# %%
import pandas as pd
url='pybook2.csv'
df = pd.read_csv(url)
df.groupby(['Year','Faculty']).count()
# Out:
#               STT  MSSV  HO TEN  DIEM
# Year Faculty
# 18   DDT        1     1       1     1
# 19   CKD        1     1       1     1
#      CKM        1     1       1     1
#      HH         1     1       1     1
# 20   CKM        1     1       1     1
#      CLC        1     1       1     1
#      CNM        1     1       1     1
# 22   CKM        1     1       1     1
# 23   CKM        1     1       1     1
# 24   DDT        1     1       1     1

# %%
import pandas as pd 
url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
#print('All the countries have medals',data['NOC'].unique())
data[(data['NOC']=='USA') & (data['Event gender']=='M') & (data['Medal']=='Gold')]

# %%
import pandas as pd 
url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[(data['NOC'].unique())].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-e888531149d5> in <module>
#       2 url ='http://winterolympicsmedals.com/medals.csv'
#       3 data = pd.read_csv(url)
# ----> 4 data[(data['NOC'].unique())].count()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...
